# %% [markdown]
# # MAR All data regression try 1

# %% [markdown]
# ## Import data as .csv file
# In order to do it, I saved the MARAll.csv in the same folder:

# %%
# Import 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt   # for plotting
training_data = pd.read_csv('MARAll.csv')
training_data.set_index("Observation", inplace=True)
# data = np.loadtxt("MARAll.csv")

# %%
# .loc DataFrame method
# filtering rows and selecting columns by label

# format
# .loc[rows, columns]

# row 0, all columns
X = training_data.loc[:,'F1':'F6'] # save all the Factor scores in X
y = training_data.loc[:,'Section'] # save all the section numbers in y

# %%
# construct the matrix X and the vector y
m = X.shape[0]  # m is the number of training examples
#X = np.hstack((np.ones((m,1)),x))  # np.stack simply stacks two vectors (or matrices) horizontally.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

X = [[0.44, 0.68], [0.99, 0.23]]
vector = [109.85, 155.72]
predict= [0.49, 0.18]

poly = PolynomialFeatures(degree=2)
X_ = poly.fit_transform(X)
predict_ = poly.fit_transform(predict)

clf = linear_model.LinearRegression()
clf.fit(X_, vector)
print clf.predict(predict_)
# Out:
#   File "<ipython-input-47-a2cd04b1972e>", line 14
#     print clf.predict(predict_)
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Example for Underfitting and Overfitting in Scikit-learn

# %%
# http://scikit-learn.org/0.17/auto_examples/model_selection/plot_underfitting_overfitting.html

print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation

np.random.seed(0)

n_samples = 30 # Sample Number
degrees = [1, 4, 15] # Degree of Polynomial

true_fun = lambda X: np.cos(1.5 * np.pi * X)
X = np.sort(np.random.rand(n_samples))
y = true_fun(X) + np.random.randn(n_samples) * 0.1

plt.figure(figsize=(14, 5))
for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i + 1)
    plt.setp(ax, xticks=(), yticks=())

    polynomial_features = PolynomialFeatures(degree=degrees[i],
                                             include_bias=False)
    linear_regression = LinearRegression()
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X[:, np.newaxis], y)

    # Evaluate the models using crossvalidation
    scores = cross_validation.cross_val_score(pipeline,
        X[:, np.newaxis], y, scoring="mean_squared_error", cv=10)

    X_test = np.linspace(0, 1, 100)
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.scatter(X, y, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
    plt.legend(loc="best")
    plt.title("Degree {}\nMSE = {:.2e}(+/- {:.2e})".format(
        degrees[i], -scores.mean(), scores.std()))
plt.show()
# Out:
# Automatically created module for IPython interactive environment
# /Users/xling/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /Users/xling/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /Users/xling/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# ...
